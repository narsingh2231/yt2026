# %% [markdown]
# ### Syntax and Semantics in Python
# Video Outline:
# - Single line Comments and multiline comments
# - Definition of Syntax and Semantics
# - Basic Syntax Rules in Python
# - Understanding Semantics in Python
# - Common Syntax Errors and How to Avoid Them
# - Practical Code Examples

# %% [markdown]
# Syntax means the rules of a programming language that tell you how to correctly arrange words and symbols to write a proper program.

# %% [markdown]
# Semantics refers to the meaning or the interpretation of the symbols, characters, and commands in a language. It is about what the code is supposed to do when it runs.

# %%
# This is a single line comment.


"""
This is a multi line comment.

"""



'''
This is a multi line comment.
'''
# Out:
# '\n\n\n'

# %% [markdown]
# # Indentation

# %% [markdown]
# Indentation in Python is used to show the structure of the code.
# Instead of using braces {} like other languages, Python uses spaces (indentation) to group lines of code.
#
# All lines inside the same block must have the same indentation level.

# %%
print("this line will print")
# Out:
# this line will print

# %%
a= 6

if a<=5:
    print("this is under if")
print("this is outside if")
# Out:
# this is outside if

# %%
## Basic Syntax Rules In Python

variable= 10
type(variable)
# Out:
# int

# %%
variable= 10
print(type(variable))
variable = "Maurya"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# Python is a case senstive 

Name = "Narsingh"

name = "Maurya"

# %%
print(Name)
# Out:
# Narsingh

# %%
print(name)
# Out:
# Maurya

# %%
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 a = b
#
# NameError: name 'b' is not defined

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# #
